# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-jainn/Exploratory_data_analysis/blob/main/Hotel_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1) What type of hotel does a customer book in general? 2) Which year most of customers arrive? 3) Which are the busiest months in the year of hotel booking? 4) How many booking were cancelled. 5) From which country most guests arrive. 6) How customers booked their hotel from market segment. 7) How many customers were stays in week nights and booking changes? 8) How many repeated customers? 9) Deposit type payment of customer? 10) Correlation of Data Set

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
df['previous_cancellations'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: previous_cancellations, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Ques> 1:- What type of hotel does a customer book in general?

# %%
df['hotel'].value_counts().plot(kind ='bar', color=('yellow','green'))
plt.title('Highest Hotel Booking', fontsize =25)
plt.xlabel('Hotel Names', fontsize = 20)
plt.ylabel('Number of cuntomer', fontsize = 20)
# Out:
# Text(0, 0.5, 'Number of cuntomer')

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %% [markdown]
#  Ques 2 Which year most of customers arrive?

# %%
df['arrival_date_year'].value_counts().plot(kind = 'bar', color=('orange','green'))
plt.title('Highest Customer Arrival Year', fontsize = 25)
plt.xlabel('Arrival Year', fontsize=20)
plt.ylabel('Number of Customers', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# Ques3. Which are the busiest months in the year of hotel booking?

# %%
df.groupby('arrival_date_year').arrival_date_month.value_counts().unstack(0).plot(kind='pie', subplots=True, figsize= (25,30))
plt.title('BUSIEST MONTHS IN YEAR', fontsize=25)
# Out:
# Text(0.5, 1.0, 'BUSIEST MONTHS IN YEAR')

# %% [markdown]
# which year is the busiest year with respect to hotels?
#
# Ans.  By analysing the below graph, City Hotel got highest number of reservation in the year 2016 as compared to others

# %%
df.groupby('hotel').arrival_date_year.value_counts().unstack(0).plot.bar()
plt.title('Highest Hotel Bookings', fontsize=25)
plt.xlabel('Arrival Year', fontsize=20)
plt.ylabel('Number of Customer', fontsize= 20)
# Out:
# Text(0, 0.5, 'Number of Customer')

# %%
df['previous_cancellations'].value_counts()
# Out:
# 0     112906
# 1       6051
# 2        116
# 3         65
# 24        48
# 11        35
# 4         31
# 26        26
# 25        25
# 6         22
# 19        19
# 5         19
# 14        14
# 13        12
# 21         1
# Name: previous_cancellations, dtype: int64

# %% [markdown]
# Ques 4:-How many booking were cancelled?
#
# from the below graph we can interpret that very few booking are cancelled.

# %%
df['previous_cancellations'].value_counts().plot(kind='bar')
plt.title('Cancellations Done Previously', fontsize =25)
plt.xlabel('Previous Cancellations', fontsize= 20)
plt.ylabel('Number of Customer', fontsize= 20)
# Out:
# Text(0, 0.5, 'Number of Customer')

# %% [markdown]
# Q5. From which country most guests arrive.?
#
#  Here the outcome shows that highest guests arrives from PRT country.

# %%
df['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
df['country'].value_counts(ascending = False)[:1]
# Out:
# PRT    48590
# Name: country, dtype: int64

# %% [markdown]
#  6) How customers booked their hotel from market segment.
#  It is shown that most of the bookings were done by Online TA segment.

# %%
df['market_segment'].value_counts().plot(kind='barh', color=('Orange', 'Blue'))
plt.title('Mode of Hotel Booking',fontsize=25)
plt.ylabel('Market Segments',fontsize=20)
plt.xlabel('Number of Booking',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Booking')

# %% [markdown]
# 7) How many customers were stays in week nights and booking changes?
# it is shown that the total no. of customers stays in week night and booking changes are same i.e. 119390

# %%
stay_week_night=df['stays_in_week_nights'].value_counts().sum()
booking_change= df['booking_changes'].value_counts().sum()
stay_week_night
# Out:
# 119390

# %%
booking_change
# Out:
# 119390

# %% [markdown]
# 8) How many repeated customers?
# there are total 115580 repeated guests are present

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
print("Number of Repeated Customers are = ",df['is_repeated_guest'].value_counts()[1])
# Out:
# Number of Repeated Customers are =  3810

# %% [markdown]
# 9) Deposit type payment of customer?

# %%
df['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %% [markdown]
# 10) Correlation of Data Set?

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005048  -0.037622           0.054624
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), vmin=-1, cmap='coolwarm', annot=True)
